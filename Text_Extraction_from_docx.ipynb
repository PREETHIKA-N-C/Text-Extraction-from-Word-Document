# %%
# !pip install docx2txt
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for docx2txt: filename=docx2txt-0.8-py3-none-any.whl size=3960 sha256=012951e9c4bb896e7862004a16269f1726dacff97516a105116cbe18895df0c6
#   Stored in directory: /root/.cache/pip/wheels/22/58/cf/093d0a6c3ecfdfc5f6ddd5524043b88e59a9a199cb02352966
# Successfully built docx2txt
# ...

# %%
import docx2txt
text = docx2txt.process("/content/Project_Template.docx")

# %%
type(text)
# Out:
# str

# %%
print(text)
# Out:
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
#
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
#
#
#
#
#
#
#
#
#
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
#
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
#
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
#
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
# Bannari Amman Institute of Technology
#
# Sathyamangalam 638 401
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Final Year Students
#
# Project Logbook
#
# Final Year Students
#
# Project Logbook
#
#
#
#
#
#
#
#
#
#
#
#
#
# Academic Year 2021-2022
#
#
#
# 	Department of
#
#
#
#
#
#
#
#
#
# Student’s Project Log Book
#
#
#
#
#
# B.E. / B.Tech. Degree Examinations
#
#
#
# 	Subject Code & Title:
#
#
#
#
#
#
#
# 	Student Name	:
#
#
#
# ...
